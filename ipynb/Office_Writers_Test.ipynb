# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
table_Off = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Office_(American_TV_series)_episodes')

print(f'Total tables: {len(table_Off)}')
# Out:
# Total tables: 23

# %%
table_Off[0]
# Out:
#   Season          Episodes               Originally aired                  \
#   Season Season.1 Episodes Episodes.1         First aired      Last aired
# 0    NaN        1        6          6      March 24, 2005  April 26, 2005
# 1    NaN        2       22         22  September 20, 2005    May 11, 2006
# 2    NaN        3       25         25  September 21, 2006    May 17, 2007
# 3    NaN        4       19         19  September 27, 2007    May 15, 2008
# 4    NaN        5       28         28  September 25, 2008    May 14, 2009
# 5    NaN        6       26         26  September 17, 2009    May 20, 2010
# 6    NaN        7       26         26  September 23, 2010    May 19, 2011
# 7    NaN        8       24         24  September 22, 2011    May 10, 2012
# 8    NaN        9       25         25  September 20, 2012    May 16, 2013
#
#      Rank Average viewership(in millions)
#      Rank Average viewership(in millions)
# 0  102[4]                             5.4
# ...

# %%
table_Off[1]
# Out:
#    No.overall  No. inseason            Title      Directed by  \
# 0           1             1          "Pilot"       Ken Kwapis
# 1           2             2  "Diversity Day"       Ken Kwapis
# 2           3             3    "Health Care"  Ken Whittingham
# 3           4             4   "The Alliance"     Bryan Gordon
# 4           5             5     "Basketball"     Greg Daniels
# 5           6             6       "Hot Girl"   Amy Heckerling
#
#                                           Written by Original air date [15]  \
# 0  Ricky Gervais & Stephen Merchant and Greg Daniels         March 24, 2005
# 1                                        B. J. Novak         March 29, 2005
# 2                                   Paul Lieberstein          April 5, 2005
# 3                                      Michael Schur         April 12, 2005
# 4                                       Greg Daniels         April 19, 2005
# ...

# %%
table_s1 = table_Off[1]

# %%
table_s2 = table_Off[2]

# %%
table_s3 = table_Off[3]
table_s4 = table_Off[4]
table_s5 = table_Off[5]
table_s6 = table_Off[6]
table_s7 = table_Off[7]
table_s8 = table_Off[8]
table_s9 = table_Off[9]

# %%
seasons_table = pd.concat([table_s1, table_s2, table_s3, table_s4, table_s5, table_s6, table_s7, table_s8, table_s9], axis=0)
seasons_table.head()
# Out:
#    No.overall  No. inseason            Title      Directed by  \
# 0           1             1          "Pilot"       Ken Kwapis
# 1           2             2  "Diversity Day"       Ken Kwapis
# 2           3             3    "Health Care"  Ken Whittingham
# 3           4             4   "The Alliance"     Bryan Gordon
# 4           5             5     "Basketball"     Greg Daniels
#
#                                           Written by Original air date [15]  \
# 0  Ricky Gervais & Stephen Merchant and Greg Daniels         March 24, 2005
# 1                                        B. J. Novak         March 29, 2005
# 2                                   Paul Lieberstein          April 5, 2005
# 3                                      Michael Schur         April 12, 2005
# 4                                       Greg Daniels         April 19, 2005
#
#    Prod.code [15] U.S. viewers(millions)
# 0            1001              11.20[16]
# 1            1002               6.00[17]
# ...

# %%
seasons_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              186 non-null    int64
#  1   No. inseason            186 non-null    int64
#  2   Title                   186 non-null    object
#  3   Directed by             186 non-null    object
#  4   Written by              186 non-null    object
#  5   Original air date [15]  186 non-null    object
#  6   Prod.code [15]          186 non-null    int64
#  7   U.S. viewers(millions)  186 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 13.1+ KB

# %%
seasons_table['Written by'].unique()
# Out:
# array(['Ricky Gervais & Stephen Merchant and Greg Daniels', 'B. J. Novak',
#        'Paul Lieberstein', 'Michael Schur', 'Greg Daniels',
#        'Mindy Kaling', 'Gene Stupnitsky & Lee Eisenberg', 'Larry Wilmore',
#        'Jennifer Celotta', 'Lee Eisenberg & Gene Stupnitsky',
#        'Steve Carell', 'Brent Forrester',
#        'Ricky Gervais & Stephen Merchant', 'Justin Spitzer',
#        'Michael Schur & Lee Eisenberg & Gene Stupnitsky',
#        'Lee Eisenberg & Gene Stupnitsky & Michael Schur',
#        'Caroline Williams', 'Justin Spitzer & Brent Forrester',
#        'Jennifer Celotta & Greg Daniels',
#        'Paul Lieberstein & Michael Schur', 'Lester Lewis',
#        'Brent Forrester & Justin Spitzer',
#        'Jennifer Celotta & Paul Lieberstein', 'Ryan Koh', 'Aaron Shure',
#        'Charlie Grandy', 'Anthony Q. Farrell',
#        'Warren Lieberstein & Halsted Sullivan',
#        'Greg Daniels & Mindy Kaling', 'Daniel Chun', 'Jason Kessler',
# ...

# %%
seasons_table['Written by'].value_counts()
# Out:
# Mindy Kaling                                         20
# B. J. Novak                                          15
# Paul Lieberstein                                     13
# Brent Forrester                                       9
# Justin Spitzer                                        9
# Greg Daniels                                          9
# Jennifer Celotta                                      8
# Gene Stupnitsky & Lee Eisenberg                       8
# Michael Schur                                         7
# Charlie Grandy                                        7
# Aaron Shure                                           6
# Daniel Chun                                           5
# Lee Eisenberg & Gene Stupnitsky                       5
# Carrie Kemper                                         4
# Robert Padnick                                        4
# Warren Lieberstein & Halsted Sullivan                 4
# Owen Ellickson                                        4
# ...

# %%
writers = seasons_table['Written by']

# %%
writers
# Out:
# 0     Ricky Gervais & Stephen Merchant and Greg Daniels
# 1                                           B. J. Novak
# 2                                      Paul Lieberstein
# 3                                         Michael Schur
# 4                                          Greg Daniels
#                             ...
# 18                                         Dan Sterling
# 19                Halsted Sullivan & Warren Lieberstein
# 20                                 Niki Schwartz-Wright
# 21                                      Brent Forrester
# 22                                         Greg Daniels
# Name: Written by, Length: 186, dtype: object

# %%
writers.str.split('&')
# Out:
# 0     [Ricky Gervais ,  Stephen Merchant and Greg Da...
# 1                                         [B. J. Novak]
# 2                                    [Paul Lieberstein]
# 3                                       [Michael Schur]
# 4                                        [Greg Daniels]
#                             ...
# 18                                       [Dan Sterling]
# 19             [Halsted Sullivan ,  Warren Lieberstein]
# 20                               [Niki Schwartz-Wright]
# 21                                    [Brent Forrester]
# 22                                       [Greg Daniels]
# Name: Written by, Length: 186, dtype: object

# %%
writers = seasons_table['Written by']

# %%
writers = writers.str.split('&')

# %%
writers = seasons_table['Written by']
writers = writers.str.split('&')

# %%
writers
# Out:
# 0     [Ricky Gervais ,  Stephen Merchant and Greg Da...
# 1                                         [B. J. Novak]
# 2                                    [Paul Lieberstein]
# 3                                       [Michael Schur]
# 4                                        [Greg Daniels]
#                             ...
# 18                                       [Dan Sterling]
# 19             [Halsted Sullivan ,  Warren Lieberstein]
# 20                               [Niki Schwartz-Wright]
# 21                                    [Brent Forrester]
# 22                                       [Greg Daniels]
# Name: Written by, Length: 186, dtype: object

# %%
writers.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'

# %%
writers = seasons_table['Written by']

# %%
writers.value_counts()
# Out:
# Mindy Kaling                                         20
# B. J. Novak                                          15
# Paul Lieberstein                                     13
# Brent Forrester                                       9
# Justin Spitzer                                        9
# Greg Daniels                                          9
# Jennifer Celotta                                      8
# Gene Stupnitsky & Lee Eisenberg                       8
# Michael Schur                                         7
# Charlie Grandy                                        7
# Aaron Shure                                           6
# Daniel Chun                                           5
# Lee Eisenberg & Gene Stupnitsky                       5
# Carrie Kemper                                         4
# Robert Padnick                                        4
# Warren Lieberstein & Halsted Sullivan                 4
# Owen Ellickson                                        4
# ...
